# %%
#Introduction_Say "Hello, World!" With Python

print("Hello, World!")

# %%
#Introduction_Python If-Else

import math
import os
import random
import re
import sys


if __name__ == '__main__':
    n = int(input().strip())
    if n%2!=0:
        print('Weird')
    elif n%2==0 and 2<=n<=5:
        print('Not Weird')
    elif n%2==0 and 6<=n<=20:
        print('Weird')
    elif n%2==0 and n>20:
        print('Not Weird')

# %%
#Introduction_Aritmetic Operators

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    c = int(a+b)
    d = int(a-b)
    e = int(a*b)
    print(c)
    print(d)
    print(e)

# %%
#Introduction_Python:Division

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)

# %%
#Introduction_Loops_Exercise5

if __name__ == '__main__':
    n = int(input())
    i=0
    while n>=0 and i<n:
        print(i*i)
        i=i+1

# %%
#Introduction_Write a function

def is_leap(year):
    leap = False
    
    # Write your logic here
    
    return leap

year = int(input())
print(is_leap(year))

# %%
#Introduction_Print Function

if __name__ == '__main__':
    n = int(input())
    s=""
    for i in range(1,n+1):
        i=str(i)
        s=s+i
print(s)

# %%
#Basic Data Types_List Comprehensions_

if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    lista=[]
    for i in range(0,x+1):
        for j in range(0,y+1):
            for k in range(0,z+1):
                listin=[i,j,k,]
                if(sum(listin)!=n):
                    lista.append(listin)
                else:
                    n2=n
    print(lista)

# %%
#Basic Data Types_Find the Runner-Up Score!

if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    top=-60000
    runner=-60000
    for i in arr:
        if(i>runner):
            if(i>top):
                runner=top
                top=i
            elif(i<top):
                runner=i
print(runner)

# %%
#Basic Data Types_Nested Lists

if __name__ == '__main__':
    score_lst=[]
    lst=[]
    for _ in range(int(input())):
        name = input()
        score = float(input())
        score_lst.append(score)
        lst.append([name,score])
    second_low=sorted(list(set(score_lst)))[1]
    names=[name for name, scores in sorted(lst) if scores==second_low]
    print('\n'.join(names))

# %%
#Basic Data Types_Finding the percentage

if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    a=student_marks[query_name]
    b=sum(a)/3
    c=round(b,2)
    print('%.2f' %c)

# %%
#Basic Data Types_Lists

if __name__ == '__main__':
    N = int(input())
    a=[]
    for i in range(N):
        b=input().split()
        if b[0] == "print":
            print(a)
        elif b[0] == "insert":
            a.insert(int(b[1]),int(b[2]))
        elif b[0] == "remove":
            a.remove(int(b[1]))
        elif b[0] == "pop":
            a.pop()
        elif b[0] == "append":
            a.append(int(b[1]))
        elif b[0] == "sort":
            a.sort()
        else:
            a.reverse()

# %%
#Basic Data Types_Tuples

if __name__ == '__main__':
    n = int(raw_input())
    integer_list = map(int, raw_input().split())
    t=tuple(integer_list)
    print hash(t)

# %%
#Strings_sWAP cASE

def swap_case(s):
    output=''
    for x in s:
        if(x.isupper()==True):
            output += x.lower()
        elif(x.islower()==True):
            output += x.upper()
        else:
            output += x      
    return output

# %%
#Strings_String Split and Join

def split_and_join(line):
    # write your code here
    line = line.split(" ")
    line = "-".join(line)
    return line

# %%
#Strings_What's Your Name?

def print_full_name(first, last):
    # Write your code here
    last +="!"
    print("Hello", first, last,"You just delved into python.")

# %%
#Strings_Mutations

def mutate_string(string, position, character):
    l=list(string)
    l[position]=character
    string=''.join(l)
    return string

# %%
#Strings_Find a string

def count_substring(string, sub_string):
    count=0
    for i in range(len(string)-len(sub_string)+1):
        if string[i:i+len(sub_string)]==sub_string:
            count += 1
    return count

# %%
#Strings_String Validators

if __name__ == '__main__':
    s = input()
    for i in range(len(s)):
        if(s[i].isalnum()==True):
            print (True)
            break
    else:
        print(False) 
    for i in range(len(s)):
        if(s[i].isalpha()==True):
            print (True)
            break
    else:
        print(False)
    for i in range(len(s)):
        if(s[i].isdigit()==True):
            print(True)
            break
    else:
        print(False)
    for i in range(len(s)):
        if(s[i].islower()==True):
            print(True)
            break
    else:
        print(False)
    for i in range(len(s)):
        if(s[i].isupper()==True):
            print(True)
            break
    else:
         print(False)

# %%
#Strings_Text Alignment

t = int(input()) #This must be an odd number
c = 'H'

for i in range(t):
    print((c*i).rjust(t-1)+c+(c*i).ljust(t-1))
    
for i in range(t+1):
    print((c*t).center(t*2)+(c*t).center(t*6))


for i in range((t+1)//2):
    print((c*t*5).center(t*6))    


for i in range(t+1):
    print((c*t).center(t*2)+(c*t).center(t*6))    


for i in range(t):
    print(((c*(t-i-1)).rjust(t)+c+(c*(t-i-1)).ljust(t)).rjust(t*6))

# %%
#Strings_Text Wrap

def wrap(string, max_width):
    for i in range(0,len(string),max_width):
        b=string[i:i+max_width]
        if len(b)==max_width:
            print(b)
        else:
            return(b)

# %%
#Strings_Designer Door Mat

N, M=map(int,input().split())
for i in range(1,N,2):
    print(str('.|.'*i).center(M, '-'))
print('WELCOME'.center(M,'-'))
for i in range(N-2,-1,-2):
    print(str('.|.'*i).center(M, '-'))

# %%
#Strings_String Formatting

def print_formatted(number):
    # your code goes here
    l1=len(bin(number)[2:])
    
    for i in range(1,number+1):
        print(str(i).rjust(l1,' '), end=" ")
        print(oct(i)[2:].rjust(l1,' '),end=" ")
        print(((hex(i)[2:]).upper()).rjust(l1,' '),end=" ")
        print(bin(i)[2:].rjust(l1,' '))

# %%
#Strings_Alphabet Rangoli

def print_rangoli(size):
    # your code goes here
    n=size
    alphabet=list(map(chr,range(97,123)))
    x=alphabet[n-1::-1]+alphabet[1:n]
    w=len('-'.join(x))
    for i in range(1,n):
        print('-'.join(alphabet[n-1:n-i:-1]+alphabet[n-i:n]).center(w,'-'))
    for i in range(n,0,-1):
        print('-'.join(alphabet[n-1:n-i:-1]+alphabet[n-i:n]).center(w,'-'))

# %%
#Strings_Capitalize!

def solve(s):
    sp=s.split()
    for i in sp:
        s=s.replace(i,i.capitalize())
    return s

# %%
#Strings_The Minion Game

def minion_game(string):
    n=len(s)
    s1=0
    s2=0
    vocali='AEIOU'
    for i in range(n):
        if s[i] not in vocali:
            s1=s1+(len(s)-i)
        else:
            s2=s2+(len(s)-i)
    if s1>s2:
        print("Stuart",s1)
    elif s2>s1:
        print("Kevin",s2)
    else:
        print("Draw")

# %%
#Strings_Merge the Tools!

def merge_the_tools(string, k):
    s=''
    a=0
    for i in string:
            if i not in s:
                s=s+i
            a=a+1
            if(a==k):
                print(s)
                a=0
                s=''
                
                
    print(s, '\n')

# %%
#Sets_Introduction to Sets

def average(array):
    # your code goes here
    sum=0
    b=set(array)
    for i in b:
        sum+=i
    average=sum/len(b)
    return average

# %%
#Sets_No Idea!

s=input().split()
count=0
storage=list(map(int, input().split()))
A=set(map(int,input().split()))
B=set(map(int,input().split()))
for i in storage:
    if i in A:
        count = count+1
    if i in B:
        count = count -1       
print(count)

# %%
#Sets_Symmetric Difference

M=int(input())
a=set(map(int,input().split()))
N=int(input())
b=set(map(int,input().split()))
diff1=(a.difference(b))
diff2=(b.difference(a))
L=[]
for i in range(0, len(diff1)):
    n=int(diff1.pop())
    L.append(n)
for i in range(0, len(diff2)):
    n=int(diff2.pop())
    L.append(n)
L.sort()
for i in L:
    print(i)

# %%
#Sets_Set .add()

N=int(input())
a=set()
for i in range(N):
    a.add(input())
print(len(a))

# %%
#Sets_Set .union() Operation

n=int(input())
A=list(map(int, input().split()))
b=int(input())
B=list(map(int, input().split()))
l=[]
for i in B:
    l.append(i)
    
for o in A:
    l.append(o)
    
s=set(l)
print(len(s))

# %%
#Sets_Set .intersection() Operation

n=input().split()
n1=set(input().split())
b=input().split()
b1=set(input().split())
inter=n1.intersection(b1)
print(len(inter))

# %%
#Sets_Set .difference() Operation

n=input().split()
n_students=set(input().split())
m=input().split()
m_students=set(input().split())
diff = n_students.difference(m_students)
print(len(diff))

# %%
#Sets_Set .symmetric_difference() Operation

n=input().split()
n_students=set(input().split())
m=input().split()
m_students=set(input().split())
diff = n_students.symmetric_difference(m_students)
print(len(diff))

# %%
#Sets_Set Mutations

n_A=input()
A=set(map(int, input().split()))
number_sets=int(input())
for i in range(number_sets):
    operation=input().split()
    if operation[0]=="intersection_update":
        B=set(map(int, input().split()))
        A.intersection_update(B)
    elif operation[0]=="update":
        B=set(map(int,input().split()))
        A.update(B)
    elif operation[0]=="symmetric_difference_update":
        B=set(map(int,input().split()))
        A.symmetric_difference_update(B)
    elif operation[0]=="difference_update":
        B=set(map(int,input().split()))
        A.difference_update(B)  
print(sum(A))

# %%
#Sets_The Captain's Room

size_group=int(input())
A=sorted(input().split())
n_people=len(A)
n_group=int((n_people-1)/size_group)
for i in range(n_people):
    if(i != n_people-1):
        if(A[i] != A[i-1] and A[i]!=A[i+1]):
            print(A[i])
            break
    else:
        print(A[i])

# %%
#Sets_Check Subset

n_test=int(input())
for i in range(n_test):
    nA=int(input())
    A=set(input().split())
    nB=int(input())
    B=set(input().split())
    print(A.issubset(B))

# %%
#Sets_Check Strict Superset

A=set(input().split())
N=int(input())
output=True
for i in range(N):
    B=set(input().split())
    if not B.issubset(A):
        output=False
    if len(B) >= len(A):
        output=False
print(output)

# %%
#Sets_Set .discard(), .remove() & .pop()

n = int(input())
s = set(map(int,input().split()))
m = int(input())
for i in range(m):
    a = input().split()
    if a[0]=="remove":
        s.remove(int(a[1]))
    elif a[0]=="discard":
        s.discard(int(a[1]))
    else :
        s.pop()
print(sum(list(s)))

# %%
#Collections_collections.Counter()

from collections import Counter
n_shoes=input()
shopList=Counter(map(int,input().split()))
n_customers= int(input())
total=0
for i in range(n_customers):
    size,price=map(int, input().split())
    if size in shopList and shopList[size]>0:
        shopList[size]=shopList[size]-1
        total=total+price
print(total)

# %%
#Collections_DefaultDict Tutorial

from collections import defaultdict
d=defaultdict(list)
n,m=map(int,input().split())
for i in range(n):
    d[input()].append(str(i+1))
for j in range(m):
    print(' '.join(d[input()])or -1)

# %%
#Collections_Collections.namedtuple()

from collections import namedtuple
tot_students=int(input())
c_name= ','.join(input().split())
columns_name=namedtuple('columns_name',c_name)
sum=0
for i in range(tot_students):
    student=input().split()
    Student=columns_name(*student)
    sum=sum+int(Student.MARKS)
print(sum/tot_students)

# %%
#Collections_Collections.OrderedDict()

from collections import OrderedDict
N_items=int(input())
d=OrderedDict()
for i in range(N_items):
    item=input().split()
    item_name=" ".join(item[:-1])
    item_price=int(item[-1])
    if(d.get(item_name)):
        d[item_name]= d[item_name]+ item_price
    else:
        d[item_name]=item_price
for i in d.keys():
    print(i, d[i])

# %%
#Collections_Word Order

n = input()
s = {}
for i in range(int(n)):
    k= input()
    if k in s:
        s[k] = s[k]+1
    else:
        s[k] = 1
print(len(s))
for i in s:
    print(s[i], end=" ")

# %%
#Collections_Collections.deque()

from collections import deque

archivio = deque()
n = int(input())

for i in range(n):
    a = input().split()
    if(a[0] == 'append'):
        archivio.append(a[1])
    elif(a[0] == 'popleft'):
        archivio.popleft()
    elif(a[0] == 'appendleft'):
        archivio.appendleft(a[1])
    elif(a[0] == 'pop'):
        archivio.pop()

print(' '.join(archivio))

# %%
#Collections_Company Logo

import math
import os
import random
import re
import sys

if __name__ == '__main__':
    s = input()

d={}
for i in sorted(s):
    if i in d:
        d[i]+=1
    else:
        d[i]=1
d=dict(sorted(d.items(), key=lambda item: item[1],reverse=True))
count=0
for c in d:
    if count == 3:
        break
    else:
        print(c,d[c])
        count+=1

# %%
#Collections_Piling Up!

n=int(input())
for t in range(n):
    input()
    l = list(map(int, input().split()))
    l1 = len(l)
    i = 0
    while i < l1 - 1 and l[i] >= l[i+1]:
        i += 1
    while i < l1 - 1 and l[i] <= l[i+1]:
        i += 1
    print ("Yes" if i == l1 - 1 else "No")

# %%
#Date and Time_Calendar Module

import calendar
m,d,y = map(int, input().split())
c=calendar.weekday(y,m,d)
if c==0:
    print("MONDAY")
elif c==1:
    print("TUESDAY")
elif c==2:
    print("WEDNESDAY")
elif c==3:
    print("THURSDAY")
elif c==4:
    print("FRIDAY")
elif c==5:
    print("SATURDAY")
elif c==6:
    print("SUNDAY")

# %%
#Date and Time_Time Delta

import math
import os
import random
import re
import sys
from datetime import datetime
def time_delta(t1, t2):
    formato_tempo="%a %d %b %Y %H:%M:%S %z"
    tempo1= datetime.strptime(t1, formato_tempo)
    tempo2= datetime.strptime(t2, formato_tempo)
    return str(int(abs(tempo1-tempo2).total_seconds()))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')
    t = int(input())
    for t_itr in range(t):
        t1 = input()
        t2 = input()
        delta = time_delta(t1, t2)
        fptr.write(delta + '\n')

    fptr.close()

# %%
#Errors and Exceptions_Exceptions

T=int(input())
for i in range(T): 
     try:
        l=list(input().split())
        a=int(l[0])
        b=int(l[1])
        print (a//b)
     except ZeroDivisionError as e:
        print("Error Code:",e)
     except ValueError as v:
        print("Error Code:",v)

# %%
#Built-Ins_Zipped!

N,X=input().split()
l=list()
for i in range(int(X)):
    A=list(map(float, input().split()))
    l.append(A)
for i in zip(*l):
    print(sum(i)/len(i))

# %%
#Built-Ins_Athlete Sort

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    nm = input().split()
    n = int(nm[0])
    m = int(nm[1])
    arr = []
    for _ in range(n):
        arr.append(list(map(int, input().split())))
    k = int(input()) 
    P=sorted(arr, key=lambda a:a[k])
    for i in range(len(P)):
        for j in range(len(P[i])):
            print(P[i][j], end=' ')     
        print()

# %%
#Built-Ins_ginortS
def sort_String(s):
    odd_case=[]
    even_case=[]
    lower_case=[]
    upper_case=[]
    
    for char in s:
        
        if char.isupper():
            upper_case.append(char)
        elif char.islower():
            lower_case.append(char)
        elif char.isdigit():
            if int(char)%2==0:
                even_digits.append(char)
            else:
                odd_digits.append(char)
    return(''.join(sorted(lower_case)+sorted(upper_case)+sorted(odd_digits)+sorted(even_digits)))
if __name__=='__main__':
    S=input()
    print(sort_String(S))

# %%
#Python Functionals_Map and Lambda Function

cube = lambda x: x**
def fibonacci(n):
    # return a list of fibonacci numbers
    s=[0,1]
    for i in range(2,n):
        s.append(s[i-1]+s[i-2])
    return(s[0:n])

# %%
#Regex and Parsing_Detect Floating Point Number

T=int(input())
for i in range(T):
    ans=False
    try:
        string=input()
        float(string)
        ans=True
        int(string)
        ans=False
    except:
        pass
    print(ans)

# %%
#Regex and Parsing_Re.split()
regex_pattern = r"[.,]+"

# %%
#Regex and Parsing_Group(), Groups() & Groupdict()

import re
s = re.search(r"([a-z0-9])\1+", input())
if s:
    print(s.group(1))
else:
    print(-1)

# %%
#Regex and Parsing_Re.findall() & Re.finditer()

import re
s=input()
vocali="aeiouAEIOU"
consonanti="qwrtypsdfghjklzxcvbnmQWRTYPSDFGHJKLZXCVBNM"
l=re.findall(r"(?<=[%s])([%s]{2,})[%s]"%(consonanti,vocali,consonanti),s)

if not l:
    print(-1)
else:
    for i in l:
        print(i)

# %%
#Regex and Parsing_Re.start() & Re.end()

import re 
s=input()
k=input()
a=re.compile(k)
b=a.search(s)
if not b:
    print("(-1, -1)")
else:
    while b:
        print("({0}, {1})".format(b.start(), b.end() - 1))
        b=a.search(s, b.start() + 1)

# %%
#Regex and Parsing_Regex Substitution

import re 
    
N = int(input())
for i in range(N):
    print(re.sub(r'(?<= )(&&|\|\|)(?= )', lambda x: 'and' if x.group() == '&&' else 'or', input()))

# %%
#Regex and Parsing_Validating Roman Numerals

regex_pattern = r""	
thousand = 'M{0,3}'
hundred = '(C[MD]|D?C{0,3})'
ten = '(X[CL]|L?X{0,3})'
digit = '(I[VX]|V?I{0,3})'
regex_pattern = r"%s%s%s%s$" % (thousand, hundred, ten, digit)

# %%
#Regex and Parsing_Validating phone numbers

N=int(input())
for i in range(N):
    t=input()
    tl=list(t)
    if(len(tl)==10 and tl[0] in ['7', '8', '9'] and t.isnumeric()):
        print("YES")
    else:
        print("NO")

# %%
#Regex and Parsing_Validating and Parsing Email Addresses

import email.utils
import re
N =int(input())
for i in range(N):
    a = email.utils.parseaddr(input())
    if bool(re.match('[a-zA-Z](\w|-|\.)+@[a-zA-Z]+\.[a-zA-Z]{0,3}$', a[1])):
        print(email.utils.formataddr(a))

# %%
#Regex and Parsing_Hex Color Code

import re
N=int(input())
in_css=False
for i in range(N):
    l=input()
    if '{' in l:
        in_css=True
    elif '}' in l:
        in_css=False
    elif in_css==True:
        for i in re.findall('#[0-9a-fA-F]{3,6}',l):
            print(i)

# %%
#Regex and Parsing_HTML Parser - Part 1

from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start :", tag)
        for i in attrs:
            print('->', i[0], '>', i[1])
    def handle_endtag(self, tag):
        print ("End   :", tag)
    def handle_startendtag(self, tag, attrs):
        print ("Empty :", tag)
        for i in attrs:
            print('->', i[0], '>', i[1])
            
Myparser = MyHTMLParser()
Myparser.feed(''.join([input() for i in range(int(input()))]))

# %%
#Regex and Parsing_HTML Parser - Part 2

from html.parser import HTMLParser
class MyHTMLParser(HTMLParser):
    def handle_comment(self, data):
        number_of_line = len(data.split('\n'))
        if number_of_line>1:
            print('>>> Multi-line Comment')
        else:
            print('>>> Single-line Comment')
        if data.strip():
            print(data)

    def handle_data(self, data):
        if data.strip():
            print(">>> Data")
            print(data)

parser = MyHTMLParser()

html_string = ''
for i in range(int(input())):
    html_string += input().rstrip()+'\n'
    
parser.feed(html_string)
parser.close()

# %%
#Regex and Parsing_Detect HTML Tags, Attributes and Attribute Values

from html.parser import HTMLParser
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print(tag)
        for i in attrs:
            print('->', i[0], '>', i[1])

N = int(input())
Myparser = MyHTMLParser()
for i in range(N):
    l= input()
    Myparser.feed(l)

# %%
#Regex and Parsing_Validating UID

import re
N=int(input())
for i in range(N):
    uid = input()
    uid = "".join(sorted(uid))
    if (re.search(r"[A-Z]{2}",uid) and #2 lettere maiuscole
        re.search(r"\d{3}",uid) and #3+ cifre
        not re.search(r"[^A-Za-z0-9]",uid) and #solo alfanumerici
        not re.search(r"(\w)\1",uid) and #no ripetizioni
        len(uid) == 10): 
        print("Valid")
    else:
        print("Invalid")

# %%
#Regex and Parsing_Validating Credit Card Numbers

import re
N=int(input())
for i in range(N):
    s = input()
    if re.match(r"^[456]([\d]{15}|[\d]{3}(-[\d]{4}){3})$", s) and not re.search(r"([\d])\1\1\1", s.replace("-", "")):
        print("Valid")
    else:
        print("Invalid")

# %%
#Regex and Parsing_Validating Postal Codes

regex_integer_in_range = r"^[1-9][\d]{5}$"

regex_alternating_repetitive_digit_pair = r"(\d)(?=\d\1)"

# %%
#Regex and Parsing_Matrix Script

import math
import os
import random
import re
import sys




first_multiple_input = input().rstrip().split()

n = int(first_multiple_input[0])
m = int(first_multiple_input[1])
matrix = []

for _ in range(n):
    matrix_item = input()
    matrix.append(matrix_item)

matrix = list(zip(*matrix))
s = str()
for words in matrix:
    for char in words:
        s += char   
print(re.sub(r'(?<=\w)([^\w\d]+)(?=\w)', ' ', s))

# %%
#XML_XML 1 - Find the Score

def get_attr_number(node):
    # your code goes here
    count = 0
    for i in node:
        count = count + get_attr_number(i)
        
    return count + len(node.attrib)

# %%
#XML_XML2 - Find the Maximum Depth

maxdepth = 0
def depth(elem, level):
    global maxdepth
    # your code goes here
    if (level == maxdepth):
        maxdepth += 1
    for child in elem:
        depth(child, level + 1)

# %%
#Closures and Decorators_Standardize Mobile Number Using Decorators
def wrapper(f):
    def fun(l):
        # complete the function
        a=[]
        b=[]
        for i in l:
            b=""
            b=i[::-1][0:10][::-1]
            b=" ".join(["+91"]+[b[0:5], b[5:]])
            a.append(b)
        f(a)
    return fun

# %%
#Closures and Decorators_Decorators 2 - Name Directory

def person_lister(f):
    def inner(people):
         return map(f, sorted(people, key=lambda x: int(x[2])))
    return inner

# %%
#Numpy_Arrays

def arrays(arr):
    return numpy.array(arr, float)[::-1]

# %%
#Numpy_Shape and Reshape

import numpy
n=list(map(int,input().split()))
my_array = numpy.array(n)
print (numpy.reshape(my_array,(3,3)))

# %%
#Numpy_Transpose and Flatten

import numpy
r,c=input().split()
arr=[]
for i in range(int(r)):
    a=list(map(int,input().split()))
    arr.append(a)
my_array=numpy.array(arr)
print(numpy.transpose(my_array))
print (my_array.flatten())

# %%
#Numpy_Concatenate

import numpy
n,m,p=input().split()
A = numpy.array([input().split() for i in range(int(n))], int)
B = numpy.array([input().split() for i in range(int(m))],int)
print(numpy.concatenate((A, B), axis = 0))

# %%
#Numpy_Zeros and Ones

import numpy
n= tuple(map(int, input().split()))
print(numpy.zeros(n, dtype=numpy.int))
print(numpy.ones(n, dtype=numpy.int))

# %%
#Numpy_Eye and Identity

import numpy
numpy.set_printoptions(legacy='1.13')
n,m=map(int, input().split())
print (numpy.eye(n,m))

# %%
#Numpy_Array Mathematics

import numpy
n,m=map(int, input().split())
A = numpy.array([input().split() for i in range(int(n))],int)
B = numpy.array([input().split() for i in range(int(n))],int)
print(A+B)
print(A-B)
print(A*B)
print(A//B)
print(A%B)
print(A**B)

# %%
#Numpy_Floor, Ceil and Rint

import numpy
numpy.set_printoptions(legacy='1.13')
my_array=numpy.array(list(map(float, input().split())))
print (numpy.floor(my_array))
print (numpy.ceil(my_array))
print (numpy.rint(my_array))

# %%
#Numpy_Sum and Prod

import numpy
n,m=map(int, input().split())
my_array = numpy.array([input().split() for i in range(int(n))],int)
s=numpy.sum(my_array, axis=0)
print(numpy.prod(s,axis=0))

# %%
#Numpy_Min and Max

import numpy
n,m=map(int, input().split())
my_array = numpy.array([input().split() for i in range(int(n))],int)
minimo=numpy.min(my_array, axis=1)
print(numpy.max(minimo))

# %%
#Numpy_Mean, Var, and Std

import numpy
n,m=map(int, input().split())
l = []
for i in range(n):
    a = list(map(int, input().split()))
    l.append(a)
l = numpy.array(l)

print(numpy.mean(l, axis = 1))
print(numpy.var(l, axis = 0))
print(numpy.round(numpy.std(l), decimals=11))

# %%
#Numpy_Dot and Cross

import numpy
n=input()
A= numpy.array([input().split() for i in range(int(n))],int)
B= numpy.array([input().split() for i in range(int(n))],int)
print(numpy.dot(A,B))

# %%
#Numpy_Inner and Outer

import numpy
A=list(map(int,input().split()))
B=list(map(int,input().split()))
print(numpy.inner(A, B))
print(numpy.outer(A, B))

# %%
#Numpy_Polynomials

import numpy
p =list(map(float, input().split()))
x= input()
print(numpy.polyval(p,int(x)))

# %%
#Numpy_Linear Algebra

import numpy
numpy.set_printoptions(legacy='1.13')
n=input()
A= numpy.array([input().split() for i in range(int(n))],float)
print(numpy.linalg.det(A))
